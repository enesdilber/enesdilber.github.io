# %% [markdown]
# # Lab 2: More ggplot and dplyr

# %%
library(tidyverse)
options(repr.plot.height=4)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# randomly sampling a subset from dataset
set.seed(108)
rand_idx = runif(1000, min=1, max=dim(diamonds)[1])
dm = diamonds[rand_idx, ]
names(dm)
summary(dm)
# Out:
#  [1] "carat"   "cut"     "color"   "clarity" "depth"   "table"   "price"
#  [8] "x"       "y"       "z"
#      carat               cut      color      clarity        depth
#  Min.   :0.2200   Fair     : 29   D:115   SI1    :238   Min.   :55.80
#  1st Qu.:0.3700   Good     : 96   E:182   VS2    :226   1st Qu.:61.00
#  Median :0.6900   Very Good:224   F:164   VS1    :176   Median :61.80
#  Mean   :0.7809   Premium  :239   G:215   SI2    :153   Mean   :61.76
#  3rd Qu.:1.0300   Ideal    :412   H:150   VVS2   : 86   3rd Qu.:62.50
#  Max.   :2.4200                   I:111   VVS1   : 71   Max.   :69.70
#                                   J: 63   (Other): 50
#      table           price               x               y
#  Min.   :53.00   Min.   :  394.0   Min.   :3.910   Min.   :3.880
#  1st Qu.:56.00   1st Qu.:  854.8   1st Qu.:4.638   1st Qu.:4.628
#  Median :57.00   Median : 2174.5   Median :5.570   Median :5.585
#  Mean   :57.46   Mean   : 3814.0   Mean   :5.681   Mean   :5.685
#  3rd Qu.:59.00   3rd Qu.: 5329.2   3rd Qu.:6.492   3rd Qu.:6.520
#  Max.   :95.00   Max.   :18797.0   Max.   :8.800   Max.   :8.780
#
#        z
#  Min.   :2.310
#  1st Qu.:2.840
#  Median :3.460
#  Mean   :3.509
#  3rd Qu.:4.020
#  Max.   :5.370

# %% [markdown]
# # ggplot

# %% [markdown]
# ![Caption for the picture.](./graph1.png)

# %%
p1 = ggplot(dm) + 
    geom_point(aes(x, price, color = cut)) + 
    facet_wrap(vars(clarity), ncol=4)
print(p1)
# Out:
# plot without title

# %% [markdown]
# ## Geometric objects
# So far we have plotted the points in a fundamental manner. We might be interested in trends of the data that we have.

# %%
p2 = ggplot(dm) +
    geom_point(aes(x, price)) +
    geom_smooth(aes(x, price))
print(p2)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# ### Exercise 1
# In the above fit, use locally weighted scatterplot smoother instead general additive model.

# %% [markdown]
# ![Caption for the picture.](./graph3.png)

# %%
p3 = ggplot(dm) + 
    geom_point(aes(x, price)) + 
    geom_smooth(aes(x, price), method = "loess")
p3
# Out:
# plot without title

# %% [markdown]
# ### Exercise 2.1
# Fit a linear line

# %%
p4 = ggplot(dm) + 
    geom_point(aes(x, price)) + 
    geom_smooth(aes(x, price), method = "lm")
p4
# Out:
# plot without title

# %% [markdown]
# ### Exercise 2.2 (You do not need to do anything if your previous code is correct)
# Fit a linear line in log scale

# %%
p4 +scale_x_continuous(trans='log10') + 
    scale_y_continuous(trans='log10')
# Out:
# plot without title

# %% [markdown]
# ### Why would log-log plot make sense?
# * log-log plot describes the relationship $Price = c \cdot Carat^k$ for some constant $c, k > 0$. You could imagine that going from 0.1 carat to 0.2 carat may not increase much value, but increasing 1.9 carats to 2.0 carats would result in a significant increase in price. Let's look at the following relationship
# $$ Price = c \cdot Carat^k \Rightarrow \log Price = \log c + k \log x$$
# * You can see that once we transform both variables with log, we have a linear relationship between $\log Price$ and $\log Carat$.

# %% [markdown]
# ### Exercise 2.3
# Make separate linear lines for each category of the clarity variable

# %%
p4 = ggplot(dm) + 
    geom_point(aes(x, price, color = clarity)) + 
    geom_smooth(aes(x, price, color = clarity), method = "lm", se = F)
p4
# Out:
# plot without title

# %% [markdown]
# ### Exercise 3
# How to reduce the code duplication above? "(x=x, y=price)" is in both lines.

# %%
p5 = ggplot(dm, aes(x, price, color = clarity)) + 
    geom_point() + 
    geom_smooth(method = "lm")
p5
# Out:
# plot without title

# %% [markdown]
# ### Some other parameters

# %%
p6 = ggplot(dm, aes(x, price, color = clarity)) + 
    geom_point() + 
    geom_smooth(method = "lm", se = F ) + theme(legend.position = "none")
p6
# Out:
# plot without title

# %% [markdown]
# 1. What does show.legend=FALSE do?
# 2. What does the se argument in geom_smooth do?

# %% [markdown]
# ### Homework (You do not need to turn it in)
# 1. What geom would you use to draw a line chart? A boxplot? A histogram? An area chart?
# 2. Run this code in your head and predict what the output will look like. Then, run the code in R and check your predicions.

# %%
# Boxplot

# Histogram

# Area Chart

# %% [markdown]
# ## Statistical transformations
# Many graphs, like scatterplots, plot the raw values of your dataset. Other graphs, like bar charts, calculate new values to plot.
#
# You can learn which stat a geom uses by inspecting the default value for the 'stat' argument. For example, ?geom_bar shows that the default value for stat is 'count', which means that geom_bar() uses stat_count().
#
# stat_count() is documented on the same page as geom_bar(), and if you scroll down you can find a section called "computed variables." That describes how it computes two new variables: count and prop.
#
# Let's use the following case where we override the default stat and instead want to use a value within the dataset of the y-axis (instead of a count).

# %%
?geom_bar

# %%
popn <- tribble(
~city, ~population,
"Istanbul", 15029231,
"Moscow", 12615279,
"Saint Petersburg", 9126366,
"Berlin", 5383890,
"Madrid", 3748148
)

# %% [markdown]
# ![Caption for the picture.](./graph5.png)

# %%
ggplot(data = popn, aes(city, population)) + 
    geom_col() + ggtitle("Most Populated Cities in Europe")
# Out:
# plot without title

# %%
ggplot(data = dm) + 
    geom_bar(mapping = aes(x=cut, y=..prop.., group  = 1))
# Out:
# plot without title

# %% [markdown]
# Other times, you want to draw greater attention to the statistical transformation in your code. For example, you might use stat_summary() which summarises the y values for each unique x value, to draw attention to the summary that you're computing:

# %% [markdown]
# ![Caption for the picture.](graph6.png)

# %%
ggplot(data = dm, aes(cut, depth)) + 
    stat_summary(fun.y = mean, fun.ymin = min, fun.ymax = max, size = .3)
# Out:
# plot without title

# %% [markdown]
# ### Homework (You do not need to turn it in)
# 1. What is the default geom associated with stat_summary()? How could you rewrite the previous plot to use that geom function instead of the stat function?
# 2. What does geom_col() do? How is it different to geom_bar()?
# 3. Most geoms and stats come in pairs that are almost always used in concert. Read through the documentation and make a list of all the pairs. What do they have in common?
# 4. What variables does stat_smooth() compute? What parameters control its behaviour?
# 6. In our proportion bar chart, we need to set group = 1. Why?

# %% [markdown]
# ## Position adjustments

# %%
# Difference between color and fill
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, colour = cut))
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = cut))
# Out:
# plot without title
# plot without title

# %% [markdown]
# Remmeber that we can "color by" a different variable - in this case, clarity. By default, it stacks the bars for each clarity level. This is done using the positional adjustment specified by the position argument of geom_bar. If you don't want a stacked bar chart, you can use one of three other options: "identity", "dodge", or "fill".

# %% [markdown]
# ![Caption for the picture.](graph7.png)

# %%
ggplot(data = dm, aes(x = cut)) + 
  geom_bar(aes(fill = clarity))
# Out:
# plot without title

# %% [markdown]
# *position 'fill'*
# This works like stacking, but makes each set of stacked bars the same height. This makes it easier to compare proportions across groups.

# %%
ggplot(data = dm) + 
  geom_bar(mapping = aes(x = cut, fill = clarity), position = "fill")
# Out:
# plot without title

# %% [markdown]
# *position = 'dodge'*
#
# This places overlapping objects directly beside one another, which makes it easier to compare individual values.

# %% [markdown]
# ![Caption for the picture.](graph10.png)

# %%
ggplot(data = dm) + 
  geom_bar(mapping = aes(x = cut, fill = clarity), position = "dodge")
# Out:
# plot without title

# %% [markdown]
# A positional adjustment that is very useful for scatterplots with overlaps is the 'jitter' argument.

# %%
ggplot(data = dm) + 
  geom_point(mapping = aes(x = cut, y = price))

ggplot(data = dm) + 
  geom_point(mapping = aes(x = cut, y = price), position = "jitter")
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### Homework (I'm not going to check it)
# 1. What parameters to geom_jitter() control the amount of jittering?
# 2. Compare and contrast geom_jitter() with geom_count().
# 3. What's the default position adjustment from geom_boxplot()? Create a visualization of the mpg dataset and demostrate it.
# Make sure you go through coordinate systems.
#
# # dplyr for data manipulation

# %%
dim(dm)
head(dm)
# Out:
# [1] 1000   10
#   carat cut       color clarity depth table price x    y    z
# 1 2.26  Ideal     G     SI2     61.9  57    12831 8.44 8.36 5.20
# 2 1.56  Very Good I     VS1     62.7  58     9857 7.42 7.37 4.64
# 3 1.01  Ideal     D     VS2     62.7  57     7792 6.39 6.36 4.00
# 4 0.50  Ideal     J     VS2     62.5  53      915 5.09 5.12 3.19
# 5 1.50  Very Good G     VS2     61.1  60    13528 7.40 7.30 4.49
# 6 0.71  Very Good E     VS1     63.3  59     2946 5.64 5.67 3.58

# %% [markdown]
# Simply run 'dm' after declaring the dm variable above. can you guess what 'dbl', 'ord', and 'int' are?
#
# Notice how the levels below follow an order. Indeed, we expect Fair < Good < Very Good < Premium < Ideal

# %%
print(levels(dm$cut))
print(levels(dm$color))
print(levels(dm$clarity))
# Out:
# [1] "Fair"      "Good"      "Very Good" "Premium"   "Ideal"
# [1] "D" "E" "F" "G" "H" "I" "J"
# [1] "I1"   "SI2"  "SI1"  "VS2"  "VS1"  "VVS2" "VVS1" "IF"

# %%
sizes = c("M", "S", "S", "M", "XL", "XXL", "XL", "S", "M", "L")
levels(as.factor(sizes))
# Out:
# [1] "L"   "M"   "S"   "XL"  "XXL"

# %%
sizes = ordered(sizes, levels = c("S", "M", "L", "XL", "XXL"))
levels(sizes) # in R Studio, this will output the ordering explicitly with less-than signs
# Out:
# [1] "S"   "M"   "L"   "XL"  "XXL"

# %%
sizes
# Out:
#  [1] M   S   S   M   XL  XXL XL  S   M   L
# Levels: S < M < L < XL < XXL

# %% [markdown]
# There are five functions in dplyr: filter, arrange, select, mutate and summarise. all of them have the following properties:
# 1. The first argument is a data frame.
# 2. The subsequent arguments describe what to do with the data frame, using the variable names( without quotes).
# 3. The result is a new data frame.

# %% [markdown]
# ## Filter
# Used if you want to view or store a new dataset containing a subset of the full dataset.

# %%
filter(dm, cut == 'Fair', color == 'J')
# Out:
#   carat cut  color clarity depth table price x    y    z
# 1 1.36  Fair J     SI2     67.8  55    4158  6.73 6.66 4.54
# 2 0.71  Fair J     SI2     65.5  61    1409  5.54 5.49 3.61

# %% [markdown]
# Usually you want to store the newly subsetted data in memory.

# %%
worst_diamonds = filter(dm, cut == 'Fair', color == 'J')

# %% [markdown]
# Make sure to use '==' instead of '='. The former is to test equality while the latter is for assignments.

# %%
4 == 6
test = 6
test
test == 5
# Out:
# [1] FALSE
# [1] 6
# [1] FALSE

# %% [markdown]
# ## Use cases

# %%
length(levels(dm$cut))
# Out:
# [1] 5

# %%
levels(dm$cut)[length(levels(dm$cut))]
# Out:
# [1] "Ideal"

# %%
a = filter(dm, color == 'D' | color == 'J') 
# filtering for rows that satisfy one or both of the conditions

b = filter(dm, color == 'D' & color == 'J') 
# filtering for rows that satisfy both conditions

c = filter(dm, xor(color == 'D',color == 'J')) 
# filtering for rows that satisfy exactly one condition

best_cuts = filter(dm, cut == levels(cut)[length(levels(cut))]) 
# filtering using membership condition

not_worst_cuts = filter(dm, cut != levels(cut)[1]) 
# can do this because cut is an ordinal variable

# %%
not_worst_cuts[1:20,]
# Out:
#    carat cut       color clarity depth table price x    y    z
# 1  2.26  Ideal     G     SI2     61.9  57.0  12831 8.44 8.36 5.20
# 2  1.56  Very Good I     VS1     62.7  58.0   9857 7.42 7.37 4.64
# 3  1.01  Ideal     D     VS2     62.7  57.0   7792 6.39 6.36 4.00
# 4  0.50  Ideal     J     VS2     62.5  53.0    915 5.09 5.12 3.19
# 5  1.50  Very Good G     VS2     61.1  60.0  13528 7.40 7.30 4.49
# 6  0.71  Very Good E     VS1     63.3  59.0   2946 5.64 5.67 3.58
# 7  2.29  Premium   I     SI1     61.8  59.0  18797 8.52 8.45 5.24
# 8  1.01  Premium   E     SI1     61.8  60.0   5279 6.36 6.40 3.94
# 9  2.02  Ideal     H     SI1     62.4  58.0  17141 8.07 8.03 5.02
# 10 2.00  Ideal     J     VS2     61.0  57.0  14323 8.08 8.13 4.94
# 11 0.52  Ideal     G     VVS2    61.4  55.3   1957 5.18 5.21 3.19
# 12 1.54  Ideal     J     VS1     62.0  53.0   8207 7.41 7.49 4.62
# 13 0.31  Very Good G     SI1     61.8  55.0    490 4.35 4.38 2.69
# 14 0.42  Premium   F     VVS1    60.5  58.0   1389 4.84 4.81 2.92
# 15 0.41  Ideal     G     VS2     62.5  56.0    827 4.72 4.75 2.96
# 16 1.13  Ideal     D     VVS2    61.7  57.0  12150 6.65 6.68 4.11
# 17 0.59  Very Good G     SI1     59.3  58.0   1555 5.45 5.51 3.25
# 18 1.50  Premium   J     SI1     61.2  61.0   7518 7.43 7.37 4.53
# 19 0.30  Ideal     G     VVS2    61.8  57.0    665 4.29 4.32 2.66
# 20 1.04  Very Good H     I1      61.6  61.0   3203 6.45 6.47 3.98

# %% [markdown]
# In R, if you want to find if a variable's value is missing, use the is.na() function. In particular, do not check for equality with NA:

# %%
x = 4
x == NA
is.na(x)
# Out:
# [1] NA
# [1] FALSE

# %% [markdown]
# Similarly, never put an equality condition with NA in your dplyr filter() statements

# %%
# create a dataframe
df = tibble(x = c(1, NA, 3))
print(df)
# Out:
# # A tibble: 3 x 1
#       x
#   <dbl>
# 1     1
# 2    NA
# 3     3

# %%
filter(df, x>1)
# Out:
#   x
# 1 3

# %%
filter(df, is.na(x) | x > 1)
# Out:
#   x
# 1 NA
# 2  3

# %% [markdown]
# ### Homework (I'm not going to check it)
# 1. Write code using filter that will allow you to output diamonds with colors D or E and cuts Good or Very Good
# 2. Write code using filter that wil allow you to output diamonds with even-numbered prices

# %% [markdown]
# ## Arrange
# Useful for ordering rows instead of filtering for a subset of them

# %%
arrange(dm, clarity, color)[1:20,]
# Out:
#    carat cut       color clarity depth table price x    y    z
# 1  0.32  Good      D     I1      64.0  54.0   468  4.36 4.33 2.78
# 2  1.68  Good      E     I1      64.3  60.0  5765  7.44 7.48 4.80
# 3  1.00  Premium   F     I1      62.4  59.0  3344  6.34 6.38 3.97
# 4  0.84  Good      F     I1      60.8  64.0  1749  6.05 6.03 3.67
# 5  1.10  Ideal     F     I1      61.3  56.9  3623  6.62 6.68 4.08
# 6  0.96  Ideal     F     I1      60.7  55.0  2826  6.41 6.37 3.88
# 7  0.31  Premium   F     I1      62.9  59.0   394  4.33 4.29 2.71
# 8  0.80  Fair      G     I1      64.5  57.0  1715  5.86 5.83 3.77
# 9  0.70  Fair      G     I1      66.9  55.0  1001  5.60 5.52 3.72
# 10 1.04  Very Good H     I1      61.6  61.0  3203  6.45 6.47 3.98
# 11 1.23  Very Good H     I1      61.9  60.6  3835  6.79 6.85 4.22
# 12 0.90  Fair      H     I1      66.9  63.0  1758  6.04 5.91 4.00
# 13 1.50  Fair      I     I1      69.7  56.0  4704  6.94 6.90 4.82
# 14 0.98  Premium   I     I1      62.5  60.0  2064  6.31 6.25 3.93
# 15 1.50  Good      I     I1      62.6  63.0  4620  7.19 7.25 4.52
# 16 1.50  Good      I     I1      62.6  63.0  4620  7.19 7.25 4.52
# 17 1.69  Premium   I     I1      62.4  60.0  6436  7.59 7.56 4.73
# 18 1.01  Very Good D     SI2     59.9  61.0  5252  6.46 6.50 3.88
# 19 0.30  Ideal     D     SI2     63.0  55.0   574  4.26 4.25 2.68
# 20 0.83  Ideal     D     SI2     62.1  56.0  3207  6.00 6.04 3.74

# %% [markdown]
# Missing values are always sorted at the end:

# %%
df = tibble(x = c(5, NA, 2))
arrange(df, x)
# Out:
#   x
# 1  2
# 2  5
# 3 NA

# %%
arrange(df, desc(x))
# Out:
#   x
# 1  5
# 2  2
# 3 NA

# %% [markdown]
# ### Exercise
# 1. Use arrange to sort the dm dataset by describing order of the product of the x, y, and z variables. Output the first 20 rows of the new dataset.
#
# ## Select
# This is used to reduce the number of columns that we're dealing with. Useful for things like genetic data

# %%
names(dm)
# Out:
#  [1] "carat"   "cut"     "color"   "clarity" "depth"   "table"   "price"
#  [8] "x"       "y"       "z"

# %%
select(dm, carat, price)[1:20,]
# Out:
#    carat price
# 1  2.26  12831
# 2  1.56   9857
# 3  1.01   7792
# 4  0.50    915
# 5  1.50  13528
# 6  0.71   2946
# 7  2.29  18797
# 8  1.01   5279
# 9  2.02  17141
# 10 2.00  14323
# 11 0.52   1957
# 12 1.54   8207
# 13 0.31    490
# 14 0.42   1389
# 15 0.41    827
# 16 1.13  12150
# 17 0.59   1555
# 18 1.50   7518
# 19 0.30    665
# 20 1.04   3203

# %%
select(dm, carat:price)[1:20,]
# Out:
#    carat cut       color clarity depth table price
# 1  2.26  Ideal     G     SI2     61.9  57.0  12831
# 2  1.56  Very Good I     VS1     62.7  58.0   9857
# 3  1.01  Ideal     D     VS2     62.7  57.0   7792
# 4  0.50  Ideal     J     VS2     62.5  53.0    915
# 5  1.50  Very Good G     VS2     61.1  60.0  13528
# 6  0.71  Very Good E     VS1     63.3  59.0   2946
# 7  2.29  Premium   I     SI1     61.8  59.0  18797
# 8  1.01  Premium   E     SI1     61.8  60.0   5279
# 9  2.02  Ideal     H     SI1     62.4  58.0  17141
# 10 2.00  Ideal     J     VS2     61.0  57.0  14323
# 11 0.52  Ideal     G     VVS2    61.4  55.3   1957
# 12 1.54  Ideal     J     VS1     62.0  53.0   8207
# 13 0.31  Very Good G     SI1     61.8  55.0    490
# 14 0.42  Premium   F     VVS1    60.5  58.0   1389
# 15 0.41  Ideal     G     VS2     62.5  56.0    827
# 16 1.13  Ideal     D     VVS2    61.7  57.0  12150
# 17 0.59  Very Good G     SI1     59.3  58.0   1555
# 18 1.50  Premium   J     SI1     61.2  61.0   7518
# 19 0.30  Ideal     G     VVS2    61.8  57.0    665
# 20 1.04  Very Good H     I1      61.6  61.0   3203

# %%
select(dm, -(carat:price))[1:20,]
# Out:
#    x    y    z
# 1  8.44 8.36 5.20
# 2  7.42 7.37 4.64
# 3  6.39 6.36 4.00
# 4  5.09 5.12 3.19
# 5  7.40 7.30 4.49
# 6  5.64 5.67 3.58
# 7  8.52 8.45 5.24
# 8  6.36 6.40 3.94
# 9  8.07 8.03 5.02
# 10 8.08 8.13 4.94
# 11 5.18 5.21 3.19
# 12 7.41 7.49 4.62
# 13 4.35 4.38 2.69
# 14 4.84 4.81 2.92
# 15 4.72 4.75 2.96
# 16 6.65 6.68 4.11
# 17 5.45 5.51 3.25
# 18 7.43 7.37 4.53
# 19 4.29 4.32 2.66
# 20 6.45 6.47 3.98

# %% [markdown]
# Use rename(), which is a variant of select(), to rename a column and keep all the variables that aren't explicitly mentioned:

# %%
rename(dm, width=x)[1:20,]
# Out:
#    carat cut       color clarity depth table price width y    z
# 1  2.26  Ideal     G     SI2     61.9  57.0  12831 8.44  8.36 5.20
# 2  1.56  Very Good I     VS1     62.7  58.0   9857 7.42  7.37 4.64
# 3  1.01  Ideal     D     VS2     62.7  57.0   7792 6.39  6.36 4.00
# 4  0.50  Ideal     J     VS2     62.5  53.0    915 5.09  5.12 3.19
# 5  1.50  Very Good G     VS2     61.1  60.0  13528 7.40  7.30 4.49
# 6  0.71  Very Good E     VS1     63.3  59.0   2946 5.64  5.67 3.58
# 7  2.29  Premium   I     SI1     61.8  59.0  18797 8.52  8.45 5.24
# 8  1.01  Premium   E     SI1     61.8  60.0   5279 6.36  6.40 3.94
# 9  2.02  Ideal     H     SI1     62.4  58.0  17141 8.07  8.03 5.02
# 10 2.00  Ideal     J     VS2     61.0  57.0  14323 8.08  8.13 4.94
# 11 0.52  Ideal     G     VVS2    61.4  55.3   1957 5.18  5.21 3.19
# 12 1.54  Ideal     J     VS1     62.0  53.0   8207 7.41  7.49 4.62
# 13 0.31  Very Good G     SI1     61.8  55.0    490 4.35  4.38 2.69
# 14 0.42  Premium   F     VVS1    60.5  58.0   1389 4.84  4.81 2.92
# 15 0.41  Ideal     G     VS2     62.5  56.0    827 4.72  4.75 2.96
# 16 1.13  Ideal     D     VVS2    61.7  57.0  12150 6.65  6.68 4.11
# 17 0.59  Very Good G     SI1     59.3  58.0   1555 5.45  5.51 3.25
# 18 1.50  Premium   J     SI1     61.2  61.0   7518 7.43  7.37 4.53
# 19 0.30  Ideal     G     VVS2    61.8  57.0    665 4.29  4.32 2.66
# 20 1.04  Very Good H     I1      61.6  61.0   3203 6.45  6.47 3.98

# %%
select(dm, width = x)[1:20,]
# Out:
#    width
# 1  8.44
# 2  7.42
# 3  6.39
# 4  5.09
# 5  7.40
# 6  5.64
# 7  8.52
# 8  6.36
# 9  8.07
# 10 8.08
# 11 5.18
# 12 7.41
# 13 4.35
# 14 4.84
# 15 4.72
# 16 6.65
# 17 5.45
# 18 7.43
# 19 4.29
# 20 6.45

# %% [markdown]
# Another option is to use select() in conjunction with the everything() helper. This is useful if you have a handful of variables you would like to move to the start of the dtaframe

# %%
select(dm, price, carat, everything())[1:20,]
# Out:
#    price carat cut       color clarity depth table x    y    z
# 1  12831 2.26  Ideal     G     SI2     61.9  57.0  8.44 8.36 5.20
# 2   9857 1.56  Very Good I     VS1     62.7  58.0  7.42 7.37 4.64
# 3   7792 1.01  Ideal     D     VS2     62.7  57.0  6.39 6.36 4.00
# 4    915 0.50  Ideal     J     VS2     62.5  53.0  5.09 5.12 3.19
# 5  13528 1.50  Very Good G     VS2     61.1  60.0  7.40 7.30 4.49
# 6   2946 0.71  Very Good E     VS1     63.3  59.0  5.64 5.67 3.58
# 7  18797 2.29  Premium   I     SI1     61.8  59.0  8.52 8.45 5.24
# 8   5279 1.01  Premium   E     SI1     61.8  60.0  6.36 6.40 3.94
# 9  17141 2.02  Ideal     H     SI1     62.4  58.0  8.07 8.03 5.02
# 10 14323 2.00  Ideal     J     VS2     61.0  57.0  8.08 8.13 4.94
# 11  1957 0.52  Ideal     G     VVS2    61.4  55.3  5.18 5.21 3.19
# 12  8207 1.54  Ideal     J     VS1     62.0  53.0  7.41 7.49 4.62
# 13   490 0.31  Very Good G     SI1     61.8  55.0  4.35 4.38 2.69
# 14  1389 0.42  Premium   F     VVS1    60.5  58.0  4.84 4.81 2.92
# 15   827 0.41  Ideal     G     VS2     62.5  56.0  4.72 4.75 2.96
# 16 12150 1.13  Ideal     D     VVS2    61.7  57.0  6.65 6.68 4.11
# 17  1555 0.59  Very Good G     SI1     59.3  58.0  5.45 5.51 3.25
# 18  7518 1.50  Premium   J     SI1     61.2  61.0  7.43 7.37 4.53
# 19   665 0.30  Ideal     G     VVS2    61.8  57.0  4.29 4.32 2.66
# 20  3203 1.04  Very Good H     I1      61.6  61.0  6.45 6.47 3.98

# %% [markdown]
# There are some helper functions for select():
#     starts_with()
#     ends_with()
#     contains()
#
# ### Exercise:
# 1. Write code that wil have price as the first column and the columns starting with the letter 'c' as the following columns. Output the first 20 rows of such a datset.
#
# ### Mutate
# to create a computed column

# %%
dm_dimensions = select(dm, 
  -(carat:price)
)
mutate(dm_dimensions,
  volume = x*y*z
)[1:20,]
# Out:
#    x    y    z    volume
# 1  8.44 8.36 5.20 366.90368
# 2  7.42 7.37 4.64 253.74026
# 3  6.39 6.36 4.00 162.56160
# 4  5.09 5.12 3.19  83.13395
# 5  7.40 7.30 4.49 242.54980
# 6  5.64 5.67 3.58 114.48410
# 7  8.52 8.45 5.24 377.24856
# 8  6.36 6.40 3.94 160.37376
# 9  8.07 8.03 5.02 325.30654
# 10 8.08 8.13 4.94 324.51058
# 11 5.18 5.21 3.19  86.09108
# 12 7.41 7.49 4.62 256.41416
# 13 4.35 4.38 2.69  51.25257
# 14 4.84 4.81 2.92  67.97877
# 15 4.72 4.75 2.96  66.36320
# 16 6.65 6.68 4.11 182.57442
# 17 5.45 5.51 3.25  97.59587
# 18 7.43 7.37 4.53 248.05872
# 19 4.29 4.32 2.66  49.29725
# 20 6.45 6.47 3.98 166.09137

# %% [markdown]
# If you only want to keep the new variables, use transmute()

# %%
transmute(dm_dimensions, 
          volume = x*y*z)[1:20,]
# Out:
#    volume
# 1  366.90368
# 2  253.74026
# 3  162.56160
# 4   83.13395
# 5  242.54980
# 6  114.48410
# 7  377.24856
# 8  160.37376
# 9  325.30654
# 10 324.51058
# 11  86.09108
# 12 256.41416
# 13  51.25257
# 14  67.97877
# 15  66.36320
# 16 182.57442
# 17  97.59587
# 18 248.05872
# 19  49.29725
# 20 166.09137

# %% [markdown]
# Read Section 5.5.1 in the book for some specific functions.
#
# ### Exercise
# 1. Add a new column that converts the US dollar prices to Korean Won amounts and rounds to the nearest integer. Then order the columns as [carat, WON price, price, ...] where '...' stands for everything else. Today's exchange rate is USD = 1070 WON
#
# ## Summarise

# %%
by_color = group_by(dm, color)
summarise(by_color, avg_price = mean(price, na.rm = TRUE))
# Out:
#   color avg_price
# 1 D     2698.991
# 2 E     2847.747
# 3 F     3832.463
# 4 G     3874.070
# 5 H     4137.253
# 6 I     5249.405
# 7 J     5089.444

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
mpg2 = mpg
mpg2$year = as.factor(mpg$year) # telling it we're dealing with a category column
mpg2 = mutate(mpg2, manual = (grepl('manual', trans))) # regexp
head(mpg2)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class   manual
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact FALSE
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact  TRUE
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact  TRUE
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact FALSE
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact FALSE
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact  TRUE

# %%
by_maker_yr = group_by(mpg2, manufacturer, year)
hwy_summary = summarise(by_maker_yr,
                       count = n(),
                       hwy = mean(hwy, na.rm = TRUE),
                       cty = mean(cty, na.rm = TRUE))
hwy_summary
# Out:
#    manufacturer year count hwy      cty
# 1  audi         1999  9    26.11111 17.11111
# 2  audi         2008  9    26.77778 18.11111
# 3  chevrolet    1999  7    21.57143 15.14286
# 4  chevrolet    2008 12    22.08333 14.91667
# 5  dodge        1999 16    18.43750 13.37500
# 6  dodge        2008 21    17.57143 12.95238
# 7  ford         1999 15    18.60000 13.93333
# 8  ford         2008 10    20.50000 14.10000
# 9  honda        1999  5    31.60000 24.80000
# 10 honda        2008  4    33.75000 24.00000
# 11 hyundai      1999  6    26.66667 18.33333
# 12 hyundai      2008  8    27.00000 18.87500
# 13 jeep         1999  2    18.50000 14.50000
# 14 jeep         2008  6    17.33333 13.16667
# 15 land rover   1999  2    15.00000 11.00000
# 16 land rover   2008  2    18.00000 12.00000
# 17 lincoln      1999  2    16.50000 11.00000
# 18 lincoln      2008  1    18.00000 12.00000
# 19 mercury      1999  2    17.00000 13.50000
# 20 mercury      2008  2    19.00000 13.00000
# 21 nissan       1999  6    23.50000 17.66667
# 22 nissan       2008  7    25.57143 18.42857
# 23 pontiac      1999  3    26.33333 17.00000
# 24 pontiac      2008  2    26.50000 17.00000
# 25 subaru       1999  6    25.50000 19.00000
# 26 subaru       2008  8    25.62500 19.50000
# 27 toyota       1999 20    24.05000 18.15000
# 28 toyota       2008 14    26.14286 19.07143
# 29 volkswagen   1999 16    29.68750 21.25000
# 30 volkswagen   2008 11    28.54545 20.45455

# %%
hwy_summary_ag = filter(hwy_summary, substring(manufacturer,1,1) %in% c('a','b','c','d','e','f','g'))
hwy_summary_ag
# Out:
#   manufacturer year count hwy      cty
# 1 audi         1999  9    26.11111 17.11111
# 2 audi         2008  9    26.77778 18.11111
# 3 chevrolet    1999  7    21.57143 15.14286
# 4 chevrolet    2008 12    22.08333 14.91667
# 5 dodge        1999 16    18.43750 13.37500
# 6 dodge        2008 21    17.57143 12.95238
# 7 ford         1999 15    18.60000 13.93333
# 8 ford         2008 10    20.50000 14.10000

# %%
ggplot(data = hwy_summary_ag, mapping = aes(x = cty, y = hwy)) + 
geom_point(mapping = aes(color = manufacturer, shape = year))
# Out:
# plot without title

# %% [markdown]
# ## Pipes
# The transformations above can be written as:

# %%
hwy_summary_ag2 = mpg2 %>% 
group_by(manufacturer, year) %>%
summarise(
    count = n(),
    hwy = mean(hwy, na.rm = TRUE),
    cty = mean(cty, na.rm = TRUE)) %>%
filter(substring(manufacturer,1,1) %in% c('a','b','c','d','e','f','g'))

# %%
hwy_summary_ag2
# Out:
#   manufacturer year count hwy      cty
# 1 audi         1999  9    26.11111 17.11111
# 2 audi         2008  9    26.77778 18.11111
# 3 chevrolet    1999  7    21.57143 15.14286
# 4 chevrolet    2008 12    22.08333 14.91667
# 5 dodge        1999 16    18.43750 13.37500
# 6 dodge        2008 21    17.57143 12.95238
# 7 ford         1999 15    18.60000 13.93333
# 8 ford         2008 10    20.50000 14.10000
